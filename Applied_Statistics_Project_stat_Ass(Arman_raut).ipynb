# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# *Clean and preprocess the dataset (handling missing values, data types, etc.)*

# %%
from google.colab import drive
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pathway = "/content/sample_data/Superstore Marketing Data - Sheet1.csv"
df = pd.read_csv(pathway)
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
duplicate_rows = df.loc[df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Id, Year_Birth, Education, Marital_Status, Income, Kidhome, Teenhome, Dt_Customer, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, Response, Complain]
# Index: []
#
# [0 rows x 22 columns]

# %%
missing_values= df.isnull()
sum_of_missing_values= missing_values.sum(axis=0)
sum_of_missing_values
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
rows_with_nulls = df["Income"].isnull()
df_with_nulls = df[rows_with_nulls]
df_with_nulls
# Out:
#          Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 134    8996        1957         PhD        Married     NaN        2         1
# 262    1994        1983  Graduation        Married     NaN        1         0
# 394    3769        1972         PhD       Together     NaN        1         0
# 449    5255        1986  Graduation         Single     NaN        1         0
# 525    8268        1961         PhD        Married     NaN        0         1
# 590   10629        1973    2n Cycle        Married     NaN        1         0
# 899   10475        1970      Master       Together     NaN        0         1
# 997    9235        1957  Graduation         Single     NaN        1         1
# 1096   4345        1964    2n Cycle         Single     NaN        1         1
# 1185   7187        1969      Master       Together     NaN        1         1
# 1213   8720        1978    2n Cycle       Together     NaN        0         0
# ...

# %%
mean_income=df["Income"].mean()

# %%
df["Income"].fillna(mean_income, inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %% [markdown]
# *Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.*

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Analyze the distribution of age
plt.hist(df['Year_Birth'], bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# %%
# Analyze the distribution of education
education_counts = df['Education'].value_counts()
plt.bar(education_counts.index, education_counts.values)
plt.xlabel('Education Level')
plt.ylabel('Frequency')
plt.title('Distribution of Education')
plt.show()

# %%
# Analyze the distribution of marital status
education_counts = df['Marital_Status'].value_counts()
plt.bar(education_counts.index, education_counts.values)
plt.xlabel('Marital_Status')
plt.ylabel('Frequency')
plt.title('Distribution of Marital_Status')
plt.show()

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %%
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
df.isnull().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %%
# To summarize, for central tendency and dispersion, consider focusing on these columns:
df2_ct = df[["Id","Income","Year_Birth","Recency","MntWines","MntFishProducts","MntSweetProducts","MntGoldProds","NumWebPurchases","NumCatalogPurchases","NumStorePurchases","NumWebVisitsMonth"]]
df2_ct
# Out:
#          Id   Income  Year_Birth  Recency  MntWines  MntFishProducts  \
# 0      1826  84835.0        1970        0       189              111
# 1         1  57091.0        1961        0       464                7
# 2     10476  67267.0        1958        0       134               15
# 3      1386  32474.0        1967        0        10                0
# 4      5371  21474.0        1989        0         6               11
# ...     ...      ...         ...      ...       ...              ...
# 2235  10142  66476.0        1976       99       372               47
# 2236   5263  31056.0        1977       99         5                3
# 2237     22  46310.0        1976       99       185               15
# 2238    528  65819.0        1978       99       267              149
# 2239   4070  94871.0        1969       99       169              188
#
#       MntSweetProducts  MntGoldProds  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
mean = df2_ct.mean()
median = df2_ct.median()
mode = df2_ct.mode()

print("Mean is:\n\n",mean,"\nMedian is:\n\n",median,"\nmode is:\n\n",mode)
# print("Median is:\n\n",median)
# Out:
# Mean is:
#
#  Id                      5592.159821
# Income                 52247.251354
# Year_Birth              1968.805804
# Recency                   49.109375
# MntWines                 303.935714
# MntFishProducts           37.525446
# MntSweetProducts          27.062946
# MntGoldProds              44.021875
# NumWebPurchases            4.084821
# NumCatalogPurchases        2.662054
# NumStorePurchases          5.790179
# NumWebVisitsMonth          5.316518
# dtype: float64
# Median is:
#
#  Id                      5458.5
# Income                 51741.5
# Year_Birth              1970.0
# Recency                   49.0
# MntWines                 173.5
# MntFishProducts           12.0
# MntSweetProducts           8.0
# MntGoldProds              24.0
# NumWebPurchases            4.0
# NumCatalogPurchases        2.0
# NumStorePurchases          5.0
# NumWebVisitsMonth          6.0
# dtype: float64
# mode is:
#
# ...

# %%
var = df2_ct.var()
std = df2_ct.std()
print("Varience is:\n\n",var,"\nStandard Deviation is:\n\n",std)
# Out:
# Varience is:
#
#  Id                     1.054082e+07
# Income                 6.268913e+08
# Year_Birth             1.436179e+02
# Recency                8.388237e+02
# MntWines               1.132978e+05
# MntFishProducts        2.984325e+03
# MntSweetProducts       1.704080e+03
# MntGoldProds           2.721442e+03
# NumWebPurchases        7.721252e+00
# NumCatalogPurchases    8.544517e+00
# NumStorePurchases      1.056873e+01
# NumWebVisitsMonth      5.888606e+00
# dtype: float64
# Standard Deviation is:
#
#  Id                      3246.662198
# Income                 25037.797168
# Year_Birth                11.984069
# Recency                   28.962453
# MntWines                 336.597393
# MntFishProducts           54.628979
# MntSweetProducts          41.280498
# MntGoldProds              52.167439
# NumWebPurchases            2.778714
# NumCatalogPurchases        2.923101
# NumStorePurchases          3.250958
# NumWebVisitsMonth          2.426645
# dtype: float64

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %%
# Identify variables that could follow specific probability distributions:
# Binomial distribution:
binomial_variables = ['Complain', 'Response']

# Normal distribution:
normal_variables = ['Year_Birth', 'Income', 'MntFishProducts']


# Calculate probabilities and expected values for binomial variables:
# Probability of a customer complaining:
prob_complain = df['Complain'].mean()
print(f"Probability of a customer complaining: {prob_complain}")

# Probability of a customer accepting the offer:
prob_response = df['Response'].mean()
print(f"Probability of a customer accepting the offer: {prob_response}")


# Calculate probabilities and expected values for normal variables:
# Expected value of customer age:
expected_age = df['Year_Birth'].mean()
print(f"Expected value of customer age: {expected_age}")

# Standard deviation of customer income:
std_income = df['Income'].std()
print(f"Standard deviation of customer income: {std_income}")
# Out:
# Probability of a customer complaining: 0.009375
# Probability of a customer accepting the offer: 0.14910714285714285
# Expected value of customer age: 1968.8058035714287
# Standard deviation of customer income: 25037.797168392317

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %%
# Analyze spending habits by age group:
age_groups = df.groupby('Year_Birth')['MntWines'].mean()
plt.bar(age_groups.index, age_groups.values)
plt.xlabel('Age Group')
plt.ylabel('Average Spending on Wines')
plt.title('Spending on Wines by Age Group')
plt.show()

# %%
# Segment customers based on spending behaviours:
df['Spending_Segment'] = pd.cut(df['MntWines'], bins=3, labels=['Low', 'Medium', 'High'])

# Analyze customer segments:
segment_analysis = df.groupby('Spending_Segment').agg({'Response': 'mean', 'Income': 'mean', 'Kidhome': 'mean'})
print(segment_analysis)
# Out:
#                   Response        Income   Kidhome
# Spending_Segment
# Low               0.108722  45680.155483  0.568100
# Medium            0.216518  70378.008380  0.073661
# High              0.466102  76575.550847  0.093220
# <ipython-input-22-3e3da998e9b9>:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   segment_analysis = df.groupby('Spending_Segment').agg({'Response': 'mean', 'Income': 'mean', 'Kidhome': 'mean'})

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %%
#visualization to showcase the relationship between age and spending on wines:
plt.scatter(df['Year_Birth'], df['MntWines'])
plt.xlabel('Age')
plt.ylabel('Spending on Wines')
plt.title('Relationship between Age and Spending on Wines')
plt.show()

# %%
# Bar chart to show the average spending on wines for different customer segments:
df.groupby('Spending_Segment')['MntWines'].mean().plot(kind='bar')
plt.xlabel('Spending Segment')
plt.ylabel('Average Spending on Wines')
plt.title('Average Spending on Wines by Customer Segment')
plt.show()
# Out:
# <ipython-input-24-688a6db6bf02>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Spending_Segment')['MntWines'].mean().plot(kind='bar')

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
